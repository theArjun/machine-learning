# %% [markdown]
# # Open CV Basics
#
# 👨‍💻 **Arjun Adhikari**, June 15, 2019

# %%
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ### Read Image

# %%
img = cv2.imread('man.jpg')

# %%
plt.imshow(img)
plt.title('BGR Image')
plt.show()

# %% [markdown]
# Every color image has 3 color channels of color **Red, Green and Blue** respectively.
# And ```matplotlib``` thinks of the image as BGR channel, i.e. Red and Blue color chhannel are swapped here.

# %% [markdown]
# ### Switch Between Color Channel

# %%
img = cv2.imread('man.jpg')

new_img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
plt.imshow(new_img)
plt.show()

# %%
print(img)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[238 238 238]
#   [238 238 238]
#   [238 238 238]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  [[238 238 238]
#   [238 238 238]
#   [238 238 238]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  [[238 238 238]
#   [238 238 238]
#   [238 238 238]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]]

# %%
print(img.shape)
# Out:
# (920, 900, 3)

# %% [markdown]
# It's 3D Matrix.
# Here, the intial matrix elements are 255 because the pixel are white at corners.
