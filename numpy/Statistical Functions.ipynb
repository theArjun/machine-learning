# %% [markdown]
# # Statistical Functions

# %% [markdown]
# ✍ **Arjun Adhikari**, May 31, 2019

# %%
import numpy as np

# %%
x = np.random.randint(low=0, high=20, size=15)
print(x)
# Out:
# [14 18 17 17  1 12 18  6 13 15 12  4 14  1 13]

# %%
print(np.median(x))
# Out:
# 13.0

# %%
print(np.average(x))
# Out:
# 11.666666666666666

# %%
print(np.mean(x))
# Out:
# 11.666666666666666

# %%
print(np.std(x))
# Out:
# 5.664705542999467

# %%
print(np.var(x))
# Out:
# 32.08888888888889

# %%
print(np.histogram(x))
# Out:
# (array([2, 1, 1, 0, 0, 0, 2, 4, 1, 4], dtype=int64), array([ 1. ,  2.7,  4.4,  6.1,  7.8,  9.5, 11.2, 12.9, 14.6, 16.3, 18. ]))

# %% [markdown]
# First array is for frequency, and second is for the range.

# %%
y,z = np.histogram(x)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(x, color='red')
plt.title("Graph of random values generated")
plt.show()

# %%
plt.plot(y, 'o-', color='red')
plt.plot(z, 'o--', color='blue')
plt.title("Relation between Range and Frequency of data")
# Out:
# Text(0.5, 1.0, 'Relation between Range and Frequency of data')
