# %% [markdown]
# # Statistical Functions

# %% [markdown]
# ✍ **Arjun Adhikari**, May 31, 2019

# %%
import numpy as np

# %%
x = np.random.randint(low=0, high=20, size=15)
print(x)
# Out:
# [10  3  3  3 16  1 14 18 19  8 13 13  7 13  1]

# %%
print(np.min(x))
# Out:
# 1

# %%
print(np.max(x))
# Out:
# 19

# %%
print(np.median(x))
# Out:
# 10.0

# %%
print(np.average(x))
# Out:
# 9.466666666666667

# %%
print(np.mean(x))
# Out:
# 9.466666666666667

# %%
print(np.std(x))
# Out:
# 6.009621914526368

# %%
print(np.var(x))
# Out:
# 36.11555555555556

# %%
print(np.histogram(x))
# Out:
# (array([2, 3, 0, 2, 0, 1, 3, 1, 1, 2], dtype=int64), array([ 1. ,  2.8,  4.6,  6.4,  8.2, 10. , 11.8, 13.6, 15.4, 17.2, 19. ]))

# %% [markdown]
# First array is for frequency, and second is for the range.

# %%
y,z = np.histogram(x)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(x, color='red')
plt.title("Graph of random values generated")
plt.show()

# %%
plt.plot(y, 'o-', color='red')
plt.plot(z, 'o--', color='blue')
plt.title("Relation between Range and Frequency of data")
# Out:
# Text(0.5, 1.0, 'Relation between Range and Frequency of data')
